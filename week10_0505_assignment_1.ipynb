# %% [markdown]
# <a href="https://colab.research.google.com/github/GyeongHub/ESAA-OB/blob/main/week10_0505_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *0505(월) 10주차 과제*\
# *딥러닝 파이토치 교과서 1장 머신 러닝과 답러닝 - 01,02,03 , 2장 실습 환경 설정과 파이토치 기초 - 01,02  p.18-60*

# %% [markdown]
# # 1.1 인공지능, 머신 러닝과 딥러닝

# %% [markdown]
# **인공지능(AI)**
# - 인간의 지능을 모방하여 사람이 하는 일을 컴퓨터(기계)가 할
# 수 있도록 하는 기술.
# - 인공지능을 구현하는 방법
#     - 머신 러닝 (machine learning)
#     - 딥러닝 (deep learning)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#     인공지능 > 머신 러닝 > 딥러닝

# %% [markdown]
# **머신 러닝 vs 딥러닝 접근 방식**
#
# - 머신 러닝
#     - 주어진 데이터를 인간이 먼저 처리(전처리).
#     - 데이터의 특징을 스스로 추출하지 못함.
# - 딥러닝
#     - 인간이 하던 작업을 생략.
#     - 대량의 데이터를 신경망에 적용하면 컴퓨터가 스스로 분석한 후 답을 찾음.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 머신 러닝과 딥러닝 차이

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1.2 머신 러닝이란

# %% [markdown]
# 컴퓨터가 학습할 수 있게 하는 알고리즘과 기술을 개발하는 분야

# %% [markdown]
# ## 1.2.1 머신 러닝 학습 과정

# %% [markdown]
# 학습 단계 -> 예측 단계

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **NOTE 특성 추출**
# - 데이터별로 어떤 특징을 가지고 있는지 찾아내고, 그것을 토대로 데이터를 벡터로 변환하는 작업

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **머신 러닝의 주요 구성 요소**
# - 데이터
#     - 머신 러닝이 학습 모델을 만드는 데 사용하는 것.
#     - 보통 데이터의 80%는 훈련용, 20%는 테스트용으로 분리해서 사용.
# - 모델(모형)
#     - 머신 러닝의 학습 단계에서 얻은 최종 결과물(가설)
#     - 예를 들어 "입력 데이터의 패턴은 A와 같다"라는 가정을 머신 러닝에서는 모델이라고 함.

# %% [markdown]
# - 모델의 학습 절차
#     1. 모델(또는 가설) 선택
#     2. 모델 학습 및 평가
#     3. 평가를 바탕으로 모델 업데이트

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **NOTE 훈련과 검증, 테스트 데이터셋**
# - 검증 데이터셋을 사용하는 이유
#     - 모델 성능을 평가하기 위해서.
#     - 검증 용도의 데이터셋은 훈련 데이터셋의 일부를 떼어서 사용하기 때문에, 학습에 사용되는 데이터셋의 양이 많지 않다면 검증 데이터셋을 사용하는 것은 좋지 않음.
#
# - 모델 성능의 평가는 왜 필요할까?
#     - 검증 데이터셋을 사용해서 새롭게 수집될 데이터에 대해 예측을 평가해 볼 수 있음.
#     - 모델 성능을 높이는 데 도움을 줌.
#     - 과적합시: 정규화를 하거나 에포크(epoch)를 줄이는 방식으로 과적합을 막을 수 있음.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.2.2 머신 러닝 학습 알고리즘

# %% [markdown]
# **머신 러닝의 학습 알고리즘**
# - 지도 학습: 정답이 무엇인지 컴퓨터에 알려 주고 학습시키는 방법
# - 비지도 학습: 정답을 알려 주지 않고 특징이 비슷한 데이터를 클러스터링(범주화)하여 예측하는 학습 방법
# - 강화 학습: 자신의 행동에 대한 보상을 받으며 학습을 진행

# %% [markdown]
# **지도 학습**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **비지도 학습**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **강화 학습**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1.3 딥러닝이란

# %% [markdown]
# **딥러닝**
# - 인간의 신경망 원리를 모방한 심층 신경망 이론을 기반으로 고안된 머신 러닝 방법의 일종
# - 답러닝이 머신 러닝과 다른 큰 차이점은 인간의 뇌를 기초로 하여 설계했다는 것.
# - 컴퓨터에 뉴런과 시냅스 개념을 적용.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 수상돌기: 주변이나 다른 뉴런에서 자극을 받아들이고, 이 자극들을 전기적 신호 형태로 세포체와 축삭돌기로 보내는 역할을 함.
# - 시냅스: 신경 세포들이 이루는 연결 부위로, 한 뉴런의 축삭돌기와 다음 뉴런의 수상돌기가 만나는 부분.
# - 축삭돌기: 다른 뉴런(수상돌기)에 신호를 전달하는 기능을 하는 뉴런의 한 부분. 뉴런에서 뻗어 있는 돌기 중 가장 길며, 한 개만 있음.
# - 축삭말단: 전달된 전기 신호를 받아 신경 전달 물질을 시냅스 틈새로 방출함.

# %% [markdown]
# ## 1.3.1 딥러닝 학습 과정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 데이터 준비
#     - 파이토치나 케라스의 데이터셋 사용
#     - 캐글에서 공개된 데이터 사용
# - 모형(모델) 정의
#     - 신경망을 생성
#     - 일반적으로 은닉층 개수가 많을수록 성능이 좋아지지만 과적합 이 발생 확률이 높음. 즉 은닉층 개수에 따른 성능과 과적합은 서로 상충 관계
# - 모델(모형) 컴파일
#     - 컴파일 단계에서 활성화 함수, 손실 함수, 옵티마이저를 선택.
#     - 훈련 데이터셋 형태가 연속형: 평균 제곱 오차(MSE)
#     - 훈련 데이터셋 형태가 이진 분류: 크로스 엔트로피(cross entropy) 선택
# - 모델(모형) 훈련
#     - 적당한 데이터양을 선택.
#     - 배치와 훈련의 횟수인 에포크 선택이 중요.
#     - 최적의 파라미터, 하이퍼파라미터 찾기
# - 모델(모형) 예측
#     - 검증 데이터셋을 생성한 모델(모형)에 적용하여 실제로 예측을 진행해 보는 단계
#     - 이때 예측력이 낮다면 파라미터를 튜닝하거나 신경망 자체를 재설계 해야할 수 있음.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 딥러닝 학습 과정에서 중요한 핵심 구성 요소:
# - 신경망
# - 역전파
#
# 딥러닝이 사용하는 심층 신경망에는 데이터셋의 어떤 특성들이 중요한지 스스로에게 가르쳐 줄 수 있는 기능이 있음.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 또한, 가중치 값을 업데이트하기 위한 역전파가 중요.
#
# 특히 역전파 계산 과정에서 시용되는 미분(오치를 각 가중치로 미분)이 성능에 영향을 미치는 주요한 요소.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 파이토치를 이용하면 딥러닝 알고리즘 구현이 간단하고 편리함!

# %% [markdown]
# ## 1.3.2 딥러닝 학습 알고리즘

# %% [markdown]
# 딥러닝 학습 알고리즘
# - 지도 학습
# - 비지도 학습
# - 전이 학습

# %% [markdown]
# ---

# %% [markdown]
# **지도 학습**
#
# - 이미지 분류: 이미지 또는 비디오상의 객체를 식별하는 컴퓨터 비전 기술. 컴퓨터 비전에서 가장 많이 시용되는 것이 합성곱 신경망(CNN)
#
# - 합성곱 신경망
#     - 이미지 분류
#         - 이미지를 알고리즘에 입력하면 어떤 클래스에 속하는지 알려줌
#         - 이미지 데이터를 유사한 것끼리 분류할 때 사용
#     - 이미지 인식
#         - 사진을 분석하여 그 안에 있는 사물의 종류를 인식
#         - 의료 이미지에서 질병을 식별하거나 산업 검사 및 로봇 비전 등 다양한 분야에서 활용.
#     - 이미지 분할
#         - 영상에서 사물이나 배경 등 객체 간 영역을 픽셀 단위로 구분하는 기술

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 시계열 데이터를 분류할 때 사용되는 것: 순환 신경망(RNN)
#
# 그러나 역전파 과정에서 기울기 소멸 문제가 발생하는 단점.
# -> 문제점을 개선하고자 게이트(gate) 를 세 개 추가한 것이 LSTM.
#
# - 망각 게이트(과거 정보를 잊기 위한 게이트)
# - 입력 게이트(현재 정보를 기억하기 위한 게이트)
# - 출력 게이트(최종 결과를 위한 게이트)
#
# 를 도입하여 기울기 소멸 문제를 해결했으며 현재 시계열 문제에서 가장 활발히 사용됨.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **비지도 학습**

# %% [markdown]
# - 워드 임베딩
# - 군집

# %% [markdown]
# **워드 임베딩**
# - 컴퓨터가 이해할 수 있도록 자연어를 적절히 변환
# - 단어 의미를 벡터화하는 워드투벡터(Word2Vec) 와 글로브(GloVe) 많이 사용
# - 자연어 처리 분야의 일종으로 번역, 음성 인식 등 서비스에서 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **군집**
# - 정보가 없는 상태에서 데이터를 분류하는 방법.
# - 딥음러닝과 함께 사용하면 좋음(신경망에서 군집 알고리즘 사용).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **전이 학습**
# - 사전에 학습이 완료된 모델(사전 학습 모델)을 가지고 우리가 원하는 학습에 미세 조정 기법을 이용하여 학습시키는 방법.

# %% [markdown]
# **사전 학습 모델**
# - 풀고자 하는 문제와 비슷하면서 많은 데이터로 이미 학습이 되어 있는 모델
# - VGG, 인셉션, MobileNet 같은 사전 학습 모델을 사용하면 효율적인 학습이 가능.

# %% [markdown]
# ---

# %% [markdown]
# - 답러닝에서 지도학습 vs 비지도학습 vs 강화학습

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ---

# %% [markdown]
# # 2.1 파이토치 개요

# %% [markdown]
# **파이토치**
# - 딥러닝 프레임워크
# - 간결하고 빠른 구현성

# %% [markdown]
# ## 2.1.1 파이토치 특징 및 장점

# %% [markdown]
# GPU에서 텐서 조작 및 동적 신경망 구축이 가능한 프레임워크

# %% [markdown]
# **GPU, 텐서, 동적 신경망?**

# %% [markdown]
# - GPU(Graphics Processing Unit): 연산 속도를 빠르게 하는 역할
#     - 딥러닝에서는 기울기를 계산할 때 미분을 쓰는데, GPU를 사용하면 빠른 계산이 가능.
#     - 내부적으로 CUDA, cuDNN이라는 API를 통해 GPU를 연산에 사용할 수 있음.
#     - 병렬 연산에서 GPU의 속도는 CPU의 속도보다 훨씬 빠름 \
#      -> 딥러닝 학습에서 GPU 사용은 필수!

# %% [markdown]
# - 텐서(Tensor): 파이토치의 데이터 형태
#     - 단일 데이터 형식으로 된 자료들의 다차원 행렬
#     - 간단한 명령어(변수 뒤에 .cuda() 를 추가)를 시용해서 GPU로 연산을 수행하게 할 수 있음.

# %% [markdown]
# - 동적 신경망: 훈련을 반복할 때마다 네트워크 변경이 가능한 신경망.
#     - 학습 중에 은닉층을 추가하거나 제거히는 등 모델의 네트워크 조작이 가능.
#     - 연산 그래프를 정의하는 것과 동시에 값도 초기화되는 'Define by Run' 방식 사용 -> 연산 그래프와 연산을 분리해서 생각할 필요가 없음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **NOTE 벡터, 행렬, 텐서**
#
# - 1차원 축(행) = axis 0 = 벡터
# - 2차원 축(열) = axis 1 = 행렬
# - 3차원 축(채널) = axis 2 = 텐서

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **연산 그래프**
#
# 연산 그래프는 방향성이 있으며 변수(ex. 텐서)를 의미하는 노드와 연산(ex. 곱하기, 더하기)을 담당하는 엣지로 구성. 다음 그림과 같이 노드는 변수(a, b)를 가지고 있으며 각 계산을 통해 새로운 텐서(c, d, e)를 구성할 수 있음.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **파이토치의 장점**
#
# - 단순함(효율적인 계산)
#     - 파이썬 환경과 쉽게 통합할 수 있음.
#     - 디버깅이 직관적이고 간결함.
#
# - 성능(낮은 CPU 활용)
#     - 모델 훈련을 위한 CPU 사용률이 텐서플로와 비교하여 낮음.
#     - 학습 및 추론 속도가 빠르고 다루기 쉬움.
#
# - 직관적인 인터페이스
#     - 텐서플로처럼 잦은 API 변경이 없음.

# %% [markdown]
# ## 2.1.2 파이토치의 아키텍처

# %% [markdown]
# 크게 세 개의 계층으로 나뉨.
# - **파이토치 API**가 위치함.
# - **파이토치 엔진**이 위치함. 다차원 텐서 및 자동 미분을 처리함.
# - 텐서에 대한 **연산을 처리**함. CPU/GPU를 이용하는 텐서의 실질적인 계산을 위한 C, CUDA 등 라이브러리가 위치함.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **파이토치 API**

# %% [markdown]
# - 사용자가 이해하기 쉬운 API를 제공하여 텐서에 대한 처리와 신경망을
# 구축하고 훈련할 수 있도록 도움
# - 사용자 인터페이스를 제공하지만 실제 계산은 수행X
# - 그 대신 C++로 작성된 파이토치 엔진으로 그 작업을 전달하는 역할만 함.
# - 파이토치 API 계층에서는 사용자의 편의성을 위해 다음 패키지들이 제공됨
#     - torch: GPU를 지원하는 텐서 패키지
#     - torch.autograd: 자동 미분 패키지
#     - torch.nn: 신경망 구축 및 훈련 패키지
#     - torch.multiprocessing: 파이씬 멀티프로세싱 패키지
#     - torch.utils: DataLoader 및 기타 유틸리티를 제공하는 패키지

# %% [markdown]
# ---

# %% [markdown]
# **파이토치 엔진**

# %% [markdown]
# - 파이토치 엔진:
#     - Autograd C++
#         - 가중치, 바이어스를 업데이트하는 과정에서 필요한 미분을 자동으로 계산
#     - Aten C++
#         - C++ 텐서 라이브러리를 제공
#     - JIT C++
#         - 계산을 최적화하기 위한 JIT 컴파일러
#     - Python API
#         - 파이토치 엔진 라이브러리는 C++로 감싼 다음 Python API로 제공 -> 사용자가 손쉽게 모델 구축하고 텐서 사용 가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **연산 처리**

# %% [markdown]
# - 가장 아래 계층에 속하는 C 또는 CUDA 패키지는 상위의 API 에서 할당된 거의 모든 계산을 수행.
# - 여기에서 제공되는 패키지는 CPU / GPU(TH(토치), THC(토치 CUDA))를 이용하여 효율적인 데이터 구조 다차원 텐서에 대한 연산을 처리함.
